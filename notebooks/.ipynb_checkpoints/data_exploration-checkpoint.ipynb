# %% [markdown]
# ## Data Wrangling

# %%
import os
import cv2
import random
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, Image

from sklearn.model_selection import train_test_split

from keras.utils import to_categorical
from tensorflow.keras.preprocessing import image as k_image

# %%
# Create a list to hold data
data_list = []

# Define classes
data_path = '/Users/renatoboemer/code/edge/raw_data'
for folder in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder)
    
    # Check if the item is a directory
    if os.path.isdir(folder_path):
        for image in os.listdir(folder_path):
            image_path = os.path.join(folder_path, image)
            label = folder
            data_list.append({'image_path': image_path, 'label': label})

# Convert list to DataFrame
data = pd.DataFrame(data_list)

# %%
data.head()
# Out:
#                                           image_path   label
# 0  /Users/renatoboemer/code/edge/raw_data/cloudy/...  cloudy
# 1  /Users/renatoboemer/code/edge/raw_data/cloudy/...  cloudy
# 2  /Users/renatoboemer/code/edge/raw_data/cloudy/...  cloudy
# 3  /Users/renatoboemer/code/edge/raw_data/cloudy/...  cloudy
# 4  /Users/renatoboemer/code/edge/raw_data/cloudy/...  cloudy

# %%
print('Labels: ', data.label.unique())
classes = data.label.unique()
data['label'].value_counts()
# Out:
# Labels:  ['cloudy' 'water' 'green_area' 'desert']
# label
# cloudy        1500
# water         1500
# green_area    1500
# desert        1131
# Name: count, dtype: int64

# %% [markdown]
# ## Data Augumentation

# %% [markdown]
# The `desert` class is slightly imbalanced. To balance the dataset by augmenting the `desert` images, we will have to create an additional
# 1500−1131=**369 images**. Let's apply a couple of data augmentation techniques to address this issue:
# - rotation
# - translation
#
# Given these augmentations, each original `desert` image would generate 7 additional images (3 from rotations and 4 from translations).
#
# To achieve 369 new images, we will need to process ⌈369/7⌉=53 original `desert` images.

# %%
def rotate_image(image, angle):
    rows, cols, _ = image.shape
    M = cv2.getRotationMatrix2D((cols/2, rows/2), angle, 1) 
    return cv2.warpAffine(image, M, (cols, rows))

def translate_image(image, x_shift, y_shift):
    rows, cols, _ = image.shape
    M = np.float32([[1, 0, x_shift], [0, 1, y_shift]])
    return cv2.warpAffine(image, M, (cols, rows))

# %%
# Paths to desert images
desert_path = '/Users/renatoboemer/code/edge/raw_data/desert'
desert_image_paths = []

for image in os.listdir(desert_path):
    image_path = os.path.join(desert_path, image)
    desert_image_paths.append(image_path)

# %%
# Shuffle the paths to randomize which images we are augmenting
random.shuffle(desert_image_paths)

augmented_images = []

for i, path in enumerate(desert_image_paths[:53]):
    image = cv2.imread(path)

    # Extracting the filename without extension
    filename = os.path.basename(path)
    base_filename, file_extension = os.path.splitext(filename)
    
    # Rotations
    cv2.imwrite(os.path.join(desert_path, f"{base_filename}_rotated_-15{file_extension}"), rotate_image(image, -15))
    cv2.imwrite(os.path.join(desert_path, f"{base_filename}_rotated_15{file_extension}"), rotate_image(image, 15))
    cv2.imwrite(os.path.join(desert_path, f"{base_filename}_rotated_30{file_extension}"), rotate_image(image, 30))
    
    # Translations
    cv2.imwrite(os.path.join(desert_path, f"{base_filename}_translated_right{file_extension}"), translate_image(image, 25, 0))
    cv2.imwrite(os.path.join(desert_path, f"{base_filename}_translated_left{file_extension}"), translate_image(image, -25, 0))
    cv2.imwrite(os.path.join(desert_path, f"{base_filename}_translated_down{file_extension}"), translate_image(image, 0, 25))
    cv2.imwrite(os.path.join(desert_path, f"{base_filename}_translated_up{file_extension}"), translate_image(image, 0, -25))

# %%
# Create a list to hold data
new_data_list = []

# Define classes
data_path = '/Users/renatoboemer/code/edge/raw_data'
for folder in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder)
    
    # Check if the item is a directory
    if os.path.isdir(folder_path):
        for image in os.listdir(folder_path):
            if image.endswith(('.jpg', '.png')):
                image_path = os.path.join(folder_path, image)
                label = folder
                new_data_list.append({'image_path': image_path, 'label': label})

# %%
# Convert list to DataFrame
df = pd.DataFrame(new_data_list)

# Print total count and count per label
print(f"Total images: {len(df)}")
print(df['label'].value_counts())
# Out:
# Total images: 6002
# label
# desert        1502
# cloudy        1500
# water         1500
# green_area    1500
# Name: count, dtype: int64

# %% [markdown]
# ## Check an image

# %%
# Specify the path to your image
image_path = '/Users/renatoboemer/code/edge/raw_data/desert/desert(57).jpg'

# Read the image
img = cv2.imread(image_path)

# Check if the image was loaded successfully
if img is None:
    print("Error: Couldn't load the image.")
else:
    # Display the image in the notebook
    display(Image(data=cv2.imencode('.jpg', img)[1].tobytes()))

# %%
# Printing the size (height, width, channels)
print("image dimensions:", img.shape)

# Print image type
print(img.dtype)
# Out:
# image dimensions: (256, 256, 3)
# uint8

# %% [markdown]
# Images are in 8-bit. Ideally, we would like to train our model using 32-bit to improve accuracy but it will not be possible.

# %% [markdown]
# ## Resize & Normalize images

# %%
def resize_images_in_directory(main_directory, target_size=(224, 224)):
    """
    Resize all images in the given directory and its sub-directories to the target size.

    :param main_directory: Path to the main directory.
    :param target_size: Tuple indicating target size (width, height).
    """
    
    resized = False  # Flag to indicate if any images were resized
    
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            # Check if the file is an image
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                image_path = os.path.join(root, file)
                
                # Read and resize the image
                img = cv2.imread(image_path)
                if img is not None:  # Check if image was loaded successfully
                    resized_img = cv2.resize(img, target_size)
                    
                    # Save the resized image back to the same path, effectively replacing it
                    cv2.imwrite(image_path, resized_img)
                    resized = True  # Set the flag to indicate that at least one image was resized

    if resized:
        print("Resizing complete.")
    else:
        print("No images were resized.")

# %%
main_directory = "/Users/renatoboemer/code/edge/raw_data"
resize_images_in_directory(main_directory, target_size=(224, 224))
# Out:
# Resizing complete.

# %%
def normalize_images(main_directory):
    """
    Normalize pixel values of all images in the given directory and its sub-directories to the [0, 1] range.
    """
    
    normalized = False  # Initialize a flag to check if any images were normalized

    for root, dirs, files in os.walk(main_directory):
        for file in files:
            # Check if the file is an image (e.g., has a .jpg or .png extension).
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                image_path = os.path.join(root, file)

                # Read the image
                img = cv2.imread(image_path)
                if img is not None:  # Check if image was loaded successfully
                    # Normalize pixel values to the [0, 1] range
                    img_normalized = img.astype(np.float32) / 255.0

                    # Save the normalized image
                    cv2.imwrite(image_path, (img_normalized * 255))

                    normalized = True  # Set the flag to indicate that at least one image was normalized

    if normalized:
        print("Normalization complete.")
    else:
        print("Images not normalized.")

# %%
main_directory = "/Users/renatoboemer/code/edge/raw_data"
normalize_images(main_directory)
# Out:
# Normalization complete.

# %% [markdown]
# ## Train, Test, Split

# %%
print(len(data))
print(len(df))
# Out:
# 5631
# 6002

# %%
from keras.utils import to_categorical

# Split data into train and validation+test sets
train_df, val_test_df = train_test_split(df, test_size=0.2, random_state=42)

# Further split validation+test set into validation and test sets
val_df, test_df = train_test_split(val_test_df, test_size=0.5, random_state=42)

# %%
label_mapping = {
    'green_area': 0,
    'water': 1,
    'desert': 2,
    'cloudy': 3
}

train_df['label'] = train_df['label'].map(label_mapping)
val_df['label'] = val_df['label'].map(label_mapping)
test_df['label'] = test_df['label'].map(label_mapping)

train_labels = train_df['label'].values
val_labels = val_df['label'].values
test_labels = test_df['label'].values

# %%
# One-hot encode the labels
train_labels_ohe = to_categorical(train_labels, num_classes=4)
val_labels_ohe = to_categorical(val_labels, num_classes=4)
test_labels_ohe = to_categorical(test_labels, num_classes=4)

# %%
print("Number of training samples: ", train_df.shape[0])
print("Number of validation samples: ", val_df.shape[0])
print("Number of testing samples: ", test_df.shape[0])
# Out:
# Number of training samples:  4801
# Number of validation samples:  600
# Number of testing samples:  601

# %%
from tensorflow.keras.preprocessing import image as k_image

def load_image(img_path):
    """Loads the image as a numpy array."""
    img = k_image.load_img(img_path)
    return k_image.img_to_array(img)

# Load images for training data
train_images = np.array([load_image(img_path) for img_path in train_df['image_path']])
train_labels = train_df['label'].values

# Load images for validation data
val_images = np.array([load_image(img_path) for img_path in val_df['image_path']])
val_labels = val_df['label'].values

# Load images for test data
test_images = np.array([load_image(img_path) for img_path in test_df['image_path']])
test_labels = test_df['label'].values

# %% [markdown]
# ## Model

# %% [markdown]
# Satellites, especially those with onboard processing for tasks like image classification, have limitations when it comes to power, memory, and computational resources. This contrasts with the extensive resources available on the ground in data centers. Therefore, the convolutional neural networks (CNNs) employed on satellites tend to prioritise efficiency and resource conservation.
#
# Given those constraints, I have decided to use [Keras MobileNet](https://keras.io/api/applications/mobilenet/).
#
# MobileNet is a class of efficient deep learning neural network architectures designed primarily for mobile and edge devices, rather than server-based applications. The goal of MobileNet is to provide a lightweight model that offers good performance while being computationally efficient, thereby allowing for real-time inference on devices with limited computational resources, such as a satellite 🛰️.

# %%
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Accuracy, Precision, Recall
from tensorflow.keras.losses import CategoricalCrossentropy

# Define input shape
input_shape = (224, 224, 3)

# Create MobileNetV3-Small model
base_model = MobileNetV3Small(input_shape=input_shape, include_top=False, weights='imagenet')

# Add custom classification layers on top
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(128, activation='relu')(x)
output = Dense(4, activation='softmax')(x)

# Create the final model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss=CategoricalCrossentropy(from_logits=False),
              metrics=['accuracy', 'Precision', 'Recall'])

# %%
# # Define input shape
# input_shape = (224, 224, 3)

# # Create MobileNetV3-Small model
# base_model = MobileNetV3Small(input_shape=input_shape, include_top=False, weights='imagenet')

# # Add custom classification layers on top
# x = GlobalAveragePooling2D()(base_model.output)
# x = Dense(128, activation='relu')(x)
# output = Dense(4, activation='softmax')(x)

# # Create the final model
# model = Model(inputs=base_model.input, outputs=output)

# # Compile the model
# model.compile(optimizer=Adam(learning_rate=0.001),
#               loss=CategoricalCrossentropy(from_logits=False),
#               metrics=['accuracy', 'Precision', 'Recall'])

# %%
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_6 (Rescaling)     (None, 224, 224, 3)          0         ['input_7[0][0]']
#
#  Conv (Conv2D)               (None, 112, 112, 16)         432       ['rescaling_6[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 112, 112, 16)         64        ['Conv[0][0]']
#  lization)
#
#  tf.math.add_162 (TFOpLambd  (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]']
#  a)
#
#  re_lu_192 (ReLU)            (None, 112, 112, 16)         0         ['tf.math.add_162[0][0]']
#
#  tf.math.multiply_162 (TFOp  (None, 112, 112, 16)         0         ['re_lu_192[0][0]']
#  Lambda)
#
#  multiply_108 (Multiply)     (None, 112, 112, 16)         0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_162[0][0]']
#
#  expanded_conv/depthwise/pa  (None, 113, 113, 16)         0         ['multiply_108[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, 56, 56, 16)           144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, 56, 56, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_193 (ReLU)            (None, 56, 56, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_193[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.math.add_163 (TFOpLambd  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  a)                                                                 /Conv_1[0][0]']
#
#  re_lu_194 (ReLU)            (None, 1, 1, 16)             0         ['tf.math.add_163[0][0]']
#
#  tf.math.multiply_163 (TFOp  (None, 1, 1, 16)             0         ['re_lu_194[0][0]']
#  Lambda)
#
#  expanded_conv/squeeze_exci  (None, 56, 56, 16)           0         ['re_lu_193[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_163[0][0]']
#
#  expanded_conv/project (Con  (None, 56, 56, 16)           256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, 56, 56, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, 56, 56, 72)           1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, 56, 56, 72)           288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_195 (ReLU)            (None, 56, 56, 72)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 57, 57, 72)           0         ['re_lu_195[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 28, 28, 72)           648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 28, 28, 72)           288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_196 (ReLU)            (None, 28, 28, 72)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 28, 28, 24)           1728      ['re_lu_196[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 28, 28, 88)           2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 28, 28, 88)           352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_197 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 28, 28, 88)           792       ['re_lu_197[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 28, 28, 88)           352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_198 (ReLU)            (None, 28, 28, 88)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 28, 28, 24)           2112      ['re_lu_198[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 28, 28, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 28, 28, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 28, 28, 96)           2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 28, 28, 96)           384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_164 (TFOpLambd  (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_199 (ReLU)            (None, 28, 28, 96)           0         ['tf.math.add_164[0][0]']
#
#  tf.math.multiply_164 (TFOp  (None, 28, 28, 96)           0         ['re_lu_199[0][0]']
#  Lambda)
#
#  multiply_109 (Multiply)     (None, 28, 28, 96)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_164[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 31, 31, 96)           0         ['multiply_109[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 14, 14, 96)           2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 14, 14, 96)           384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_165 (TFOpLambd  (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_200 (ReLU)            (None, 14, 14, 96)           0         ['tf.math.add_165[0][0]']
#
#  tf.math.multiply_165 (TFOp  (None, 14, 14, 96)           0         ['re_lu_200[0][0]']
#  Lambda)
#
#  multiply_110 (Multiply)     (None, 14, 14, 96)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_165[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_110[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_166 (TFOpLambd  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_201 (ReLU)            (None, 1, 1, 96)             0         ['tf.math.add_166[0][0]']
#
#  tf.math.multiply_166 (TFOp  (None, 1, 1, 96)             0         ['re_lu_201[0][0]']
#  Lambda)
#
#  expanded_conv_3/squeeze_ex  (None, 14, 14, 96)           0         ['multiply_110[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_166[0][0]']
#
#  expanded_conv_3/project (C  (None, 14, 14, 40)           3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_167 (TFOpLambd  (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_202 (ReLU)            (None, 14, 14, 240)          0         ['tf.math.add_167[0][0]']
#
#  tf.math.multiply_167 (TFOp  (None, 14, 14, 240)          0         ['re_lu_202[0][0]']
#  Lambda)
#
#  multiply_111 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_167[0][0]']
#
#  expanded_conv_4/depthwise   (None, 14, 14, 240)          6000      ['multiply_111[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_168 (TFOpLambd  (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_203 (ReLU)            (None, 14, 14, 240)          0         ['tf.math.add_168[0][0]']
#
#  tf.math.multiply_168 (TFOp  (None, 14, 14, 240)          0         ['re_lu_203[0][0]']
#  Lambda)
#
#  multiply_112 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_168[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_112[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_169 (TFOpLambd  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_204 (ReLU)            (None, 1, 1, 240)            0         ['tf.math.add_169[0][0]']
#
#  tf.math.multiply_169 (TFOp  (None, 1, 1, 240)            0         ['re_lu_204[0][0]']
#  Lambda)
#
#  expanded_conv_4/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_112[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_169[0][0]']
#
#  expanded_conv_4/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 14, 14, 240)          9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 14, 14, 240)          960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_170 (TFOpLambd  (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_205 (ReLU)            (None, 14, 14, 240)          0         ['tf.math.add_170[0][0]']
#
#  tf.math.multiply_170 (TFOp  (None, 14, 14, 240)          0         ['re_lu_205[0][0]']
#  Lambda)
#
#  multiply_113 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_170[0][0]']
#
#  expanded_conv_5/depthwise   (None, 14, 14, 240)          6000      ['multiply_113[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 14, 14, 240)          960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_171 (TFOpLambd  (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_206 (ReLU)            (None, 14, 14, 240)          0         ['tf.math.add_171[0][0]']
#
#  tf.math.multiply_171 (TFOp  (None, 14, 14, 240)          0         ['re_lu_206[0][0]']
#  Lambda)
#
#  multiply_114 (Multiply)     (None, 14, 14, 240)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_171[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_114[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_172 (TFOpLambd  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_207 (ReLU)            (None, 1, 1, 240)            0         ['tf.math.add_172[0][0]']
#
#  tf.math.multiply_172 (TFOp  (None, 1, 1, 240)            0         ['re_lu_207[0][0]']
#  Lambda)
#
#  expanded_conv_5/squeeze_ex  (None, 14, 14, 240)          0         ['multiply_114[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_172[0][0]']
#
#  expanded_conv_5/project (C  (None, 14, 14, 40)           9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 14, 14, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 14, 14, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 14, 14, 120)          4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 14, 14, 120)          480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_173 (TFOpLambd  (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_208 (ReLU)            (None, 14, 14, 120)          0         ['tf.math.add_173[0][0]']
#
#  tf.math.multiply_173 (TFOp  (None, 14, 14, 120)          0         ['re_lu_208[0][0]']
#  Lambda)
#
#  multiply_115 (Multiply)     (None, 14, 14, 120)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_173[0][0]']
#
#  expanded_conv_6/depthwise   (None, 14, 14, 120)          3000      ['multiply_115[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, 14, 14, 120)          480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_174 (TFOpLambd  (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_209 (ReLU)            (None, 14, 14, 120)          0         ['tf.math.add_174[0][0]']
#
#  tf.math.multiply_174 (TFOp  (None, 14, 14, 120)          0         ['re_lu_209[0][0]']
#  Lambda)
#
#  multiply_116 (Multiply)     (None, 14, 14, 120)          0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_174[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_116[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_175 (TFOpLambd  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_210 (ReLU)            (None, 1, 1, 120)            0         ['tf.math.add_175[0][0]']
#
#  tf.math.multiply_175 (TFOp  (None, 1, 1, 120)            0         ['re_lu_210[0][0]']
#  Lambda)
#
#  expanded_conv_6/squeeze_ex  (None, 14, 14, 120)          0         ['multiply_116[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_175[0][0]']
#
#  expanded_conv_6/project (C  (None, 14, 14, 48)           5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 14, 14, 144)          6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 14, 14, 144)          576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_176 (TFOpLambd  (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_211 (ReLU)            (None, 14, 14, 144)          0         ['tf.math.add_176[0][0]']
#
#  tf.math.multiply_176 (TFOp  (None, 14, 14, 144)          0         ['re_lu_211[0][0]']
#  Lambda)
#
#  multiply_117 (Multiply)     (None, 14, 14, 144)          0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_176[0][0]']
#
#  expanded_conv_7/depthwise   (None, 14, 14, 144)          3600      ['multiply_117[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 14, 14, 144)          576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_177 (TFOpLambd  (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_212 (ReLU)            (None, 14, 14, 144)          0         ['tf.math.add_177[0][0]']
#
#  tf.math.multiply_177 (TFOp  (None, 14, 14, 144)          0         ['re_lu_212[0][0]']
#  Lambda)
#
#  multiply_118 (Multiply)     (None, 14, 14, 144)          0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_177[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_118[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_178 (TFOpLambd  (None, 1, 1, 144)            0         ['expanded_conv_7/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_213 (ReLU)            (None, 1, 1, 144)            0         ['tf.math.add_178[0][0]']
#
#  tf.math.multiply_178 (TFOp  (None, 1, 1, 144)            0         ['re_lu_213[0][0]']
#  Lambda)
#
#  expanded_conv_7/squeeze_ex  (None, 14, 14, 144)          0         ['multiply_118[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_178[0][0]']
#
#  expanded_conv_7/project (C  (None, 14, 14, 48)           6912      ['expanded_conv_7/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_7/project/Ba  (None, 14, 14, 48)           192       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
# ...
#  Lambda)
#
#  multiply_121 (Multiply)     (None, 7, 7, 576)            0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_182[0][0]']
#
#  expanded_conv_9/depthwise   (None, 7, 7, 576)            14400     ['multiply_121[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 7, 7, 576)            2304      ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_183 (TFOpLambd  (None, 7, 7, 576)            0         ['expanded_conv_9/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_218 (ReLU)            (None, 7, 7, 576)            0         ['tf.math.add_183[0][0]']
#
#  tf.math.multiply_183 (TFOp  (None, 7, 7, 576)            0         ['re_lu_218[0][0]']
#  Lambda)
#
#  multiply_122 (Multiply)     (None, 7, 7, 576)            0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_183[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            0         ['multiply_122[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            83088     ['expanded_conv_9/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            0         ['expanded_conv_9/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            83520     ['expanded_conv_9/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_184 (TFOpLambd  (None, 1, 1, 576)            0         ['expanded_conv_9/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_219 (ReLU)            (None, 1, 1, 576)            0         ['tf.math.add_184[0][0]']
#
#  tf.math.multiply_184 (TFOp  (None, 1, 1, 576)            0         ['re_lu_219[0][0]']
#  Lambda)
#
#  expanded_conv_9/squeeze_ex  (None, 7, 7, 576)            0         ['multiply_122[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_184[0][0]']
#
#  expanded_conv_9/project (C  (None, 7, 7, 96)             55296     ['expanded_conv_9/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_9/project/Ba  (None, 7, 7, 96)             384       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, 7, 7, 96)             0         ['expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, 7, 7, 576)            55296     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, 7, 7, 576)            2304      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.math.add_185 (TFOpLambd  (None, 7, 7, 576)            0         ['expanded_conv_10/expand/Batc
#  a)                                                                 hNorm[0][0]']
#
#  re_lu_220 (ReLU)            (None, 7, 7, 576)            0         ['tf.math.add_185[0][0]']
#
#  tf.math.multiply_185 (TFOp  (None, 7, 7, 576)            0         ['re_lu_220[0][0]']
#  Lambda)
#
#  multiply_123 (Multiply)     (None, 7, 7, 576)            0         ['expanded_conv_10/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_185[0][0]']
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            14400     ['multiply_123[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, 7, 7, 576)            2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.math.add_186 (TFOpLambd  (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#  a)                                                                 atchNorm[0][0]']
#
#  re_lu_221 (ReLU)            (None, 7, 7, 576)            0         ['tf.math.add_186[0][0]']
#
#  tf.math.multiply_186 (TFOp  (None, 7, 7, 576)            0         ['re_lu_221[0][0]']
#  Lambda)
#
#  multiply_124 (Multiply)     (None, 7, 7, 576)            0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_186[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_124[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.math.add_187 (TFOpLambd  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  a)                                                                 ite/Conv_1[0][0]']
#
#  re_lu_222 (ReLU)            (None, 1, 1, 576)            0         ['tf.math.add_187[0][0]']
#
#  tf.math.multiply_187 (TFOp  (None, 1, 1, 576)            0         ['re_lu_222[0][0]']
#  Lambda)
#
#  expanded_conv_10/squeeze_e  (None, 7, 7, 576)            0         ['multiply_124[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_187[0][0]']
#
#  expanded_conv_10/project (  (None, 7, 7, 96)             55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, 7, 7, 96)             384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, 7, 7, 96)             0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 7, 7, 576)            55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 7, 7, 576)            2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.math.add_188 (TFOpLambd  (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]']
#  a)
#
#  re_lu_223 (ReLU)            (None, 7, 7, 576)            0         ['tf.math.add_188[0][0]']
#
#  tf.math.multiply_188 (TFOp  (None, 7, 7, 576)            0         ['re_lu_223[0][0]']
#  Lambda)
#
#  multiply_125 (Multiply)     (None, 7, 7, 576)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_188[0][0]']
#
#  global_average_pooling2d_6  (None, 576)                  0         ['multiply_125[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 128)                  73856     ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  dense_13 (Dense)            (None, 4)                    516       ['dense_12[0][0]']
#
# ==================================================================================================
# Total params: 1013492 (3.87 MB)
# Trainable params: 1001380 (3.82 MB)
# Non-trainable params: 12112 (47.31 KB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_images, train_labels_ohe, 
                    validation_data=(val_images, val_labels_ohe), 
                    epochs=10, 
                    batch_size=160)
# Out:
# Epoch 1/10
# 31/31 [==============================] - 163s 4s/step - loss: 0.0973 - accuracy: 0.9640 - precision: 0.9898 - recall: 0.9506 - val_loss: 7.2453 - val_accuracy: 0.2950 - val_precision: 0.2965 - val_recall: 0.2950
# Epoch 2/10
# 31/31 [==============================] - 134s 4s/step - loss: 0.0127 - accuracy: 0.9952 - precision: 0.9956 - recall: 0.9952 - val_loss: 14.2710 - val_accuracy: 0.3567 - val_precision: 0.3567 - val_recall: 0.3567
# Epoch 3/10
# 31/31 [==============================] - 135s 4s/step - loss: 0.0143 - accuracy: 0.9956 - precision: 0.9960 - recall: 0.9956 - val_loss: 3.2540 - val_accuracy: 0.3067 - val_precision: 0.3120 - val_recall: 0.3000
# Epoch 4/10
# 31/31 [==============================] - 135s 4s/step - loss: 0.0050 - accuracy: 0.9994 - precision: 0.9996 - recall: 0.9994 - val_loss: 3.9464 - val_accuracy: 0.2350 - val_precision: 0.2354 - val_recall: 0.2350
# Epoch 5/10
# 31/31 [==============================] - 136s 4s/step - loss: 5.6293e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 4.3660 - val_accuracy: 0.2233 - val_precision: 0.2241 - val_recall: 0.2233
# Epoch 6/10
# 31/31 [==============================] - 136s 4s/step - loss: 5.9943e-04 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9998 - val_loss: 4.4604 - val_accuracy: 0.2300 - val_precision: 0.2295 - val_recall: 0.2283
# Epoch 7/10
# 31/31 [==============================] - 136s 4s/step - loss: 7.0421e-04 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9998 - val_loss: 4.6651 - val_accuracy: 0.2567 - val_precision: 0.2586 - val_recall: 0.2500
# Epoch 8/10
# 31/31 [==============================] - 137s 4s/step - loss: 0.0061 - accuracy: 0.9981 - precision: 0.9981 - recall: 0.9981 - val_loss: 4.5461 - val_accuracy: 0.3250 - val_precision: 0.3254 - val_recall: 0.3183
# Epoch 9/10
# 31/31 [==============================] - 137s 4s/step - loss: 9.9595e-04 - accuracy: 0.9996 - precision: 0.9996 - recall: 0.9996 - val_loss: 4.9607 - val_accuracy: 0.3617 - val_precision: 0.3639 - val_recall: 0.3567
# Epoch 10/10
# 31/31 [==============================] - 138s 4s/step - loss: 0.0026 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9998 - val_loss: 4.2967 - val_accuracy: 0.3433 - val_precision: 0.3440 - val_recall: 0.3217

# %%
def plot_loss_accuracy(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='best')
    plt.show()
    
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='best')
    plt.show()

plot_loss_accuracy(history)

# %%
loss, test_accuracy, test_precision, test_recall = model.evaluate(test_images, test_labels_ohe)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 19/19 [==============================] - 4s 224ms/step - loss: 4.6246 - accuracy: 0.3478 - precision: 0.3614 - recall: 0.3361
# Test accuracy: 34.78%
